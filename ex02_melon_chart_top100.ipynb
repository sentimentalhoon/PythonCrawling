# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
url = 'https://www.melon.com/chart/index.htm'
headers = {
    'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
}
# 페이지 호출
res = requests.get(url, headers = headers)
soup = bs(res.content.decode('utf-8', 'replace'), 'lxml')
topTitleList = []
topSingerList = []
rank_list = []
title = soup.select('div.ellipsis.rank01 > span > a')
print(len(title))
singer = soup.select('div.ellipsis.rank02 > span.checkEllipsis')
print(len(singer))
    
for i in range(len(singer)):
    topSingerList.append(singer[i].text)
    topTitleList.append(title[i].text)
    rank_list.append(i+1)
    print(f'{title[i].text} - {singer[i].text}')
# Out:
# 100
# 100
# Super Shy - NewJeans
# Seven (feat. Latto) - Clean Ver. - 정국
# ETA - NewJeans
# 퀸카 (Queencard) - (여자)아이들
# I AM - IVE (아이브)
# 헤어지자 말해요 - 박재정
# Spicy - aespa
# Steal The Show (From “엘리멘탈”) - Lauv
# 이브, 프시케 그리고 푸른 수염의 아내 - LE SSERAFIM (르세라핌)
# New Jeans - NewJeans
# 모래 알갱이 - 임영웅
# Hype boy - NewJeans
# 사랑은 늘 도망가 - 임영웅
# Kitsch - IVE (아이브)
# UNFORGIVEN (feat. Nile Rodgers) - LE SSERAFIM (르세라핌)
# 우리들의 블루스 - 임영웅
# Still With You - 정국
# 사막에서 꽃을 피우듯 - 우디 (Woody)
# Ditto - NewJeans
# 다시 만날 수 있을까 - 임영웅
# 무지개 - 임영웅
# Cool With You - NewJeans
# 이제 나만 믿어요 - 임영웅
# London Boy - 임영웅
# 아버지 - 임영웅
# Polaroid - 임영웅
# Attention - NewJeans
# Dynamite - 방탄소년단
# OMG - NewJeans
# 인생찬가 - 임영웅
# Summer (Feat. BE’O (비오)) - Paul Blanco
# A bientot - 임영웅
# 손이 참 곱던 그대 - 임영웅
# After LIKE - IVE (아이브)
# 사랑해 진짜 - 임영웅
# 손오공 - 세븐틴 (SEVENTEEN)
# ISTJ - NCT DREAM
# 꽃 - 지수 (JISOO)
# 연애편지 - 임영웅
# LOVE DIVE - IVE (아이브)
# Take Two - 방탄소년단
# Love Me Again - V
# 사건의 지평선 - 윤하 (YOUNHA)
# Candy - NCT DREAM
# ...

# %%
dic = {'가수이름' : topSingerList, '노래제목' : topTitleList, '순위' : rank_list}

melon = pd.DataFrame(dic)

melon.set_index('순위', inplace=True)

melon.to_csv(path_or_buf='melon.csv', encoding='utf-8')
